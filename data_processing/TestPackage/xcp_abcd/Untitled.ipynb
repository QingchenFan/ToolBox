# %%
from xcp_abcd.workflow import cifti as cifti
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-83bc8fa6715a> in <module>
# ----> 1 from xcp_abcd.workflow import cifti as cifti
#
# /GPFS/cuizaixu_lab_permanent/wuguowei/app/xcp_abcd/xcp_abcd/workflow/__init__.py in <module>
#       2 # vi: set ft=python sts=4 ts=4 sw=4 et
#       3
# ----> 4 from .connectivity import  init_fcon_ts_wf,init_cifti_conts_wf
#       5 from .postprocessing import  init_post_process_wf, init_censoring_wf,init_resd_smoohthing
#       6 from .restingstate import  (init_compute_alff_wf, init_surface_reho_wf,
#
# /GPFS/cuizaixu_lab_permanent/wuguowei/app/xcp_abcd/xcp_abcd/workflow/connectivity.py in <module>
#      15 from ..interfaces.connectivity import (nifticonnect,get_atlas_nifti,
#      16                       get_atlas_cifti,ApplyTransformsx)
# ---> 17 from ..interfaces import connectplot
# ...
