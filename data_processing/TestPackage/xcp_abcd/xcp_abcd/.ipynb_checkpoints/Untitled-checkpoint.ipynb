# %%
from xcp_abcd import workflow
# Out:
# /GPFS/cuizaixu_lab_temp/wuguowei/app/envs/xcp_abcd_py/lib/python3.8/site-packages/pybids-0.13-py3.8.egg/bids/layout/validation.py:46: UserWarning: The ability to pass arguments to BIDSLayout that control indexing is likely to be removed in future; possibly as early as PyBIDS 0.14. This includes the `config_filename`, `ignore`, `force_index`, and `index_metadata` arguments. The recommended usage pattern is to initialize a new BIDSLayoutIndexer with these arguments, and pass it to the BIDSLayout via the `indexer` argument.
#   warnings.warn("The ability to pass arguments to BIDSLayout that control "
# /GPFS/cuizaixu_lab_temp/wuguowei/app/envs/xcp_abcd_py/lib/python3.8/site-packages/niworkflows-1.3.3-py3.8.egg/niworkflows/viz/utils.py:137: SyntaxWarning: "is" with a literal. Did you mean "=="?
# ...

# %%
cifti_file = '/GPFS/cuizaixu_lab_permanent/Public_Data/HCPD/precessing/fmriprep/sub-HCD2339049/func/sub-HCD2339049_task-REST1_acq-PA_space-fsLR_den-91k_bold.dtseries.nii'
lower_bpf =
# Out:
# <function xcp_abcd.workflow.cifti.init_ciftipostprocess_wf(cifti_file, lower_bpf, upper_bpf, contigvol, bpf_order, motion_filter_order, motion_filter_type, band_stop_min, band_stop_max, smoothing, head_radius, params, output_dir, custom_conf, omp_nthreads, dummytime, fd_thresh, despike, num_cifti, layout=None, name='cifti_process_wf')>

# %%
workflow.cifti.init_ciftipostprocess_wf
# Out:
# <function xcp_abcd.workflow.cifti.init_ciftipostprocess_wf(cifti_file, lower_bpf, upper_bpf, contigvol, bpf_order, motion_filter_order, motion_filter_type, band_stop_min, band_stop_max, smoothing, head_radius, params, output_dir, custom_conf, omp_nthreads, dummytime, fd_thresh, despike, num_cifti, layout=None, name='cifti_process_wf')>

# %%
import numpy as np
import os
from nipype.pipeline import engine as pe
from numpy.core.numeric import identity
from ..utils.utils import stringforparams
from templateflow.api import get as get_template
from ..interfaces import (ConfoundMatrix,FilteringData,regress)
from ..interfaces import (interpolate,removeTR,censorscrub)
from nipype.interfaces import utility as niu
from nipype.interfaces.workbench import CiftiSmooth
from nipype.interfaces.fsl import Smooth
import sklearn
from niworkflows.engine.workflows import LiterateWorkflow as Workflow
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_168598/1903203697.py in <module>
#       3 from nipype.pipeline import engine as pe
#       4 from numpy.core.numeric import identity
# ----> 5 from ..utils.utils import stringforparams
#       6 from templateflow.api import get as get_template
#       7 from ..interfaces import (ConfoundMatrix,FilteringData,regress)
#
# ImportError: attempted relative import with no known parent package
